# %%
import wave
import sys
import matplotlib.pyplot as plt
import numpy as np
from pydub import AudioSegment
from tempfile import mktemp
import os

# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'D:\\@Extra\\Sound Filteration'

# %% [markdown]
# <h1>Plotting the original Soundwave</h1>

# %%
# Converting mp3 to wav
mp3File = AudioSegment.from_mp3(r'orcacall.mp3')
wname = mktemp('.wav')
mp3File.export(wname, format="wav")
wavFile = wave.open(wname, "r")

# %%
# Extract Raw Audio from Wav File
signal = wavFile.readframes(-1)
signal = np.frombuffer(signal, "Int16")
# Out:
# c:\users\sengu\miniconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# PLotting Waveform
plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
# Creating the spectrograph
FS, data = wavfile.read(wname)  # read wav file
plt.specgram(data[:,0], Fs=FS, xextent=(0,30))
plt.show()
# Out:
# c:\users\sengu\miniconda3\envs\tf-gpu\lib\site-packages\matplotlib\axes\_axes.py:7544: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %% [markdown]
# <h1>Plotting the synthesized Soundwave</h1>

# %%
#Reading the synthesised audio file
wavFile = wave.open("orcacallNR.wav")
# Extract Raw Audio from Wav File
signal = wavFile.readframes(-1)
signal = np.frombuffer(signal, "Int16")
# Out:
# c:\users\sengu\miniconda3\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   """

# %%
# PLotting Waveform
plt.figure(1)
plt.title("Signal Wave...")
plt.plot(signal)
plt.show()

# %%
# Pltting the spectrogram
FS, data = wavfile.read("orcacallNR.wav")  # read wav file
plt.specgram(data, Fs=FS, xextent=(0,30))
plt.show()
