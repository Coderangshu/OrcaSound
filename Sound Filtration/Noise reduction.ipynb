# %%
import tensorflow as tf
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
from IPython.display import Audio
import noisereduce as nr
from pydub import AudioSegment 
from tempfile import mktemp
# import wave
# import numpy as np
from scipy.io.wavfile import read

# %%
# Converting mp3 to wav
mp3File = AudioSegment.from_mp3(r'orcacall.mp3')
wname = mktemp('.wav')
mp3File.export(wname, format="wav")
wavFile = wave.open(wname, "r")

# %%
wav = AudioSegment.from_file(r'extracted_calls2.wav')
wname = mktemp('.wav')
wav.export(wname, format="wav")
# wavFile = wave.open(wname, "r")
# Out:
# <_io.BufferedRandom name='C:\\Users\\ANGSHU~1\\AppData\\Local\\Temp\\tmpbpacddwm.wav'>

# %%
(Frequency, array) = read(wname) # Reading the sound file.

# %%
#Audio before noise reduction
Audio(array,rate=Frequency)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# select section of data that is noise
noisy_part = array
# perform noise reduction
reduced_noise = nr.reduce_noise(audio_clip=array.astype('float64'), noise_clip=noisy_part.astype('float64'), use_tensorflow=True, verbose=False)

# %%
#Audio after noise reduction
Audio(data=reduced_noise, rate=Frequency)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import wavio

wavio.write("myfile2.wav", reduced_noise, Frequency, sampwidth=2)
